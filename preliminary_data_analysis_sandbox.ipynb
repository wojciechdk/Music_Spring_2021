# %% [markdown]
# <p style="border:2px solid black"> </p>
# <span style="font-family:Lucida Bright;">
# <p style="margin-bottom:0.8cm"></p>
# <center>
# <font size="6"><b>Understanding Music Listening Habits</b></font>
# <p style="margin-bottom:-0.1cm"></p>
# <font size="6"><b>Using Large-scale Smartphone Data</b>  </font>
#
# <p style="margin-bottom:0.5cm"></p>
# <font size="3"><b>Wojciech Mazurkiewicz, DTU, 14 May 2021</b></font>
# <p style="margin-bottom:1cm"></p>
# <font size="5"><b>Preliminary Data Analysis</b></font>
# <br>
# <font size="3"><b></b></font>
# </center>
# <p style="margin-bottom:0.4cm"></p>
# <p style="border:2px solid black"> </p>

# %% [markdown]
# # Initialization
# <hr style="border:2px solid black"></hr>

# %% [markdown]
# The initializaiton procedure is defined in the notebook [Initialization](initialization.ipynb).

# %%
# %run initialization.ipynb

# %% [markdown]
# # Create a Spark Session
# <hr style="border:2px solid black"></hr>

# %%
#%% Initialize a Spark session.
spark = t.spark.create_session('Music_Activity')

# Set this for faster conversion from Spark to pandas.
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
# Out:
# Creating a Spark session.
# 	Execution time: 6.48568 s.

# %% [markdown]
# # Load Data
# <hr style="border:2px solid black"></hr>

# %% [markdown]
# Get the paths of data files and folders:

# %%
data_root, data_subfolders, data_files = t.get_paths_raw_data()
# Out:
# Getting the data paths.
# 	Number of folders: 62
# 	Number of files: 275621

# %% [markdown]
# Load the raw and full data. The *raw* data contains the data in an unaltered table. The the *full* data contains the data, where the the columns `devices` and `tracks` are exploded, så that each row corresponds to a playback of one song on one device.

# %%
df_raw = t.load_data_from_files(data_root, spark, method='avro')
df_full = t.format_dataframe(df_raw)
# Out:
# Loading data from path: "/data/work/src/musicactivity".
# 	Execution time: 8.43431 s.
# Formatting dataframe:
# 	Exploding columns containing lists.
# 	Flattening the dataframe schema.
# 	Execution time: 0.24210

# %% [markdown]
# Now, we load a sample dataframe containing 1e6 randomly selected observations to use to gain a faster insight into the data.

# %%
path_df_1E6 = Config.Path.music_data_raw_sample_1E6_root

df_1E6 = t.load_data_from_files(path_df_1E6, spark)
# Out:
# Loading data from path: "/data/work/shared/s001284/Music_Project/resources/data/df_sample_1E6.parquet".
# 	Execution time: 5.74674 s.

# %% [markdown]
# Cache the dataframes (use only if needed):

# %%
# df_1E6.cache()
# number_of_rows_df_1E6 = t.spark.count_rows(df_1E6)

# %% [markdown]
# # Preliminary data analysis
# <hr style="border:2px solid black"></hr>

# %% [markdown]
# Take the first 100 rows of the small database and transform it to Pandas for the comfort of viewing.

# %%
df_sample_pd = df_1E6.limit(100).toPandas()

# %% [markdown]
# Get the description of the the columns from the writer schema in the avro files:

# %%
column_docs = t.get_avro_docs(data_files[0])
for column in column_docs:
    if len(column[1]) > 0:
        w.printmd(f'**{column[0]}**: *{column[1]}*')
    else:
        w.printmd(f'**{column[0]}**: *-*')
# Out:
# **id**: *Activity UUID*
# **deleted_time**: *If this activity has been deleted, this is the timestamp when it occurred*
# **useruuid**: *User UUID*
# **start_time**: *Start time*
# **end_time**: *End time*
# **devices**: *Devices used during this activity*
# **devices_name**: *Name of the device*
# 15                           Space Symphony Around Us
# 16                                           Download
# 17                                                SIA
# 18                                              Music
# 19                                After All This Time
# 20                                   Russian Roulette
# 21                            UK TOP 40 Singles Chart
# 22                                                mp3
# 23                                             audios
# 24                                             audios
# 25                                     WhatsApp Audio
# 26                                          Daydreams
# 27                                         Nature Boy
# 28                                     WhatsApp Audio
# 29                                          bluetooth
#
#                                      tracks_title  \
# 0                   Maroon 5 - Maps (Lyric Video)
# 1                                   BEAT YOU DOWN
# 2             Claudio Ismael - A tua escolha 2013
# 3                 DaizyStripper ー Brilliant Days．
# 4     Kizomba - Philipe Monteiro - Alta Segurança
# 5                             Por Fin Te Encontré
# 6                                     Handle This
# 7              Lord Pretty Flacko Jodye 2 (LPFJ2)
# 8                                           Taibo
# 9                               TairoJ'étais prêt
# 10                                            045
# 11                                          真夏の果実
# 12                 Dynamite (feat. Pretty Sister)
# 13                           Wake Up Little Susie
# 14                          No Money (zaycev.net)
# 15                                 01 Teletrambus
# 16           The Chainsmokers - Closer ft. Halsey
# 17  Flo Rida - Wild Ones ft. Sia [Official Video]
# 18                                        Phoenix
# 19                    02 Someone Had To Teach You
# 20                                    Aiming High
# 21                 Uptown Funk! (Feat.Bruno Mars)
# 22             BIGBANG - 뱅뱅뱅 (BANG BANG BANG) M-V
# 23     Calvin Harris - Outside ft. Ellie Goulding
# 24                                 Karakız (2013)
# 25                            AUD-20161014-WA0380
# 26                                    Bootleggers
# 27                                    Love Letter
# 28                             Toda Vez Que Chove
# 29                                           Burn
#
#                                      tracks_uri tracks_player  \
# 0    content://media/external/audio/media/87943       Walkman
# 1    content://media/external/audio/media/18753       Walkman
# 2     content://media/external/audio/media/2549       Walkman
# 3     content://media/external/audio/media/4816       Walkman
# 4      content://media/external/audio/media/220       Walkman
# 5    content://media/external/audio/media/73063       Walkman
# 6     content://media/external/audio/media/8402       Walkman
# 7                                                     Spotify
# 8   content://media/external/audio/media/338585       Walkman
# 9    content://media/external/audio/media/27003       Walkman
# 10  content://media/external/audio/media/144653       Walkman
# 11    content://media/external/audio/media/4999       Walkman
# 12                                                    Spotify
# 13                                                    Spotify
# 14   content://media/external/audio/media/32494       Walkman
# 15    content://media/external/audio/media/9454       Walkman
# 16   content://media/external/audio/media/91025       Walkman
# 17   content://media/external/audio/media/48620       Walkman
# 18  content://media/external/audio/media/206438       Walkman
# 19   content://media/external/audio/media/70024       Walkman
# 20  content://media/external/audio/media/111497       Walkman
# 21   content://media/external/audio/media/42349       Walkman
# 22  content://media/external/audio/media/156773       Walkman
# 23  content://media/external/audio/media/237710       Walkman
# 24   content://media/external/audio/media/56205       Walkman
# 25  content://media/external/audio/media/287970       Walkman
# 26                                                    Spotify
# 27   content://media/external/audio/media/37937       Walkman
# 28  content://media/external/audio/media/203343       Walkman
# 29    content://media/external/audio/media/6229       Walkman
#
#                                tracks_id  yearmonth
# 0                                            201610
# 1                                            201610
# 2                                            201610
# 3                                            201610
# 4                                            201610
# 5                                            201610
# 6                                            201610
# 7   spotify:track:1j6kDJttn6wbVyMaM42Nxm     201610
# 8                                            201610
# 9                                            201610
# 10                                           201610
# 11                                           201610
# 12  spotify:track:2Ae5awwKvQpTBKQHr1TYCg     201610
# 13  spotify:track:11fNLqDB47gMKj7BHhR2Qr     201610
# 14                                           201610
# 15                                           201610
# 16                                           201610
# 17                                           201610
# 18                                           201610
# 19                                           201610
# 20                                           201610
# 21                                           201610
# 22                                           201610
# 23                                           201610
# 24                                           201610
# 25                                           201610
# 26  spotify:track:2aCycHQTvCUaWIGtNT1M0x     201610
# 27                                           201610
# 28                                           201610
# 29                                           201610

# %% [markdown]
# ## Number of rows

# %% [markdown]
# Raw Database:

# %%
number_of_rows_raw = df_raw.count()
print(f'Number of rows in the raw database: {number_of_rows_raw}')
# Out:
# Number of rows in the raw database: 627101296

# %% [markdown]
# Full Database:

# %%
number_of_rows_full = df_full.count()
print(f'Number of rows in the full database: {number_of_rows_full}')
# Out:
# Number of rows in the full database: 3571278161

# %%
# For execution of the notebook without counting
number_of_rows_raw = 627101296
number_of_rows_full = 3571278161

# %% [markdown]
# ## Activity ID

# %% [markdown]
# Detecting nonempty cells:

# %%
start_time = time.time()

n_empty_id_cells = (
    df_raw
    .where(
        (f.col('id').isNull())
        | (f.col('id') == '')
        | (f.col('id') == '<unknown>')
    )
    .count()
)

print(f'Number of empty "id" cells: {n_empty_id_cells}.')
print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# Number of empty id cells: 0.
# Execution time: 338.16046 s.

# %% [markdown]
# Detecting duplicates:

# %%
start_time = time.time()

(df_raw
 .groupBy(f.col('id'))
 .count()
 .orderBy(f.desc('count'))                    
 .show(5)
)

print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# +--------------------+-----+
# |                  id|count|
# +--------------------+-----+
# |8c71293b-fe42-432...|  410|
# |ff29d186-0614-42d...|  386|
# |934c3a82-a73c-4ec...|  314|
# |a2ca4895-8074-426...|  301|
# |ae2fedfb-ef75-4ec...|  283|
# +--------------------+-----+
# only showing top 5 rows
#
# Execution time: 585.76851 s.

# %% [markdown]
# Number of duplicate activity ID's:

# %%
start_time = time.time()

number_of_duplicate_activity_ids = (
    df_raw
    .groupBy(f.col('id'))
    .count()
    .where(f.col('count') > 1)
    .count()
)

print(f"Number of duplicated activity ID's: {number_of_duplicate_activity_ids}.")
print(f'That constitutes '
      f'{number_of_duplicate_activity_ids / number_of_rows_raw * 100:.5f} % '
      f'of the total number of cells.')
print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# Number of duplicated activity ID's: 46360934.
# That constitutes 7.39289 % of the total number of cells.
# Execution time: 580.64515 s.

# %% [markdown]
# ## Activity Deleted

# %%
start_time = time.time()

n_nonempty_deleted_time_cells = (
    df_raw
    .where(
        (f.col('deleted_time').isNotNull())
        & (f.col('deleted_time') != '')
    )
    .count()
)

print(f'Number of non-empty "deleted_time" cells: {n_nonempty_deleted_time_cells}.')
print(f'That constitutes '
      f'{n_nonempty_deleted_time_cells / number_of_rows_raw * 100:.5f} % '
      f'of the total number of cells.')
print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# Number of non-empty "deleted_time" cells: 52764881.
# That constitutes 8.41409 % of the total number of cells.
# Execution time: 331.54952 s.

# %% [markdown]
# Around 8.5 % of all the activities have the "Deleted time" property set. What to do with them:
#  * Nothing
#  * Delete the column
#  * Delete the rows where the property is set

# %% [markdown]
# ## Device types

# %%
start_time = time.time()

(df_full
 .groupBy(f.col('devices_type'))
 .count()
 .orderBy(f.desc('count'))                    
 .show()
)

print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# +------------+----------+
# |devices_type|     count|
# +------------+----------+
# |       PHONE|3561473696|
# |        null|   7633807|
# |     UNKNOWN|   2170658|
# +------------+----------+
#
# Execution time: 953.80290 s.

# %% [markdown]
# Almost all the devices are phones. It could be reasonable remove the column.

# %% [markdown]
# ## Track players

# %%
start_time = time.time()

(df_full
 .groupBy(f.col('tracks_player'))
 .count()
 .orderBy(f.desc('count'))                    
 .show()
)

print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# +-------------+----------+
# |tracks_player|     count|
# +-------------+----------+
# |      Walkman|2428561686|
# |      Spotify| 710807090|
# |             | 431909382|
# |        Music|         3|
# +-------------+----------+
#
# Execution time: 997.08188 s.

# %% [markdown]
# ## Track ID vs Track URI

# %%
start_time = time.time()

n_track_id_and_uri_nonempty = (
    df_full
    .where(
        (f.col('tracks_uri') != '')
        & (f.col('tracks_uri').isNotNull())
        & (f.col('tracks_id') != '')     
        & (f.col('tracks_id').isNotNull())
    )
    .count()
)

print(f'Number of rows where both "tracks_id" and '
      f'"tracks_uri" are full: {n_track_id_and_uri_nonempty}.')
print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# Number of rows where both "tracks_id" and "tracks_uri" are full: 0.
# Execution time: 925.96000 s.

# %% [markdown]
# The Track ID and Track URI are never full at the same time. Therefore, the columns could be merged into one column.
#
# Also, the information might be redundant.
#
# We could also split the dataset into a couple of databases. Does it make sense? Maybe not.

# %% [markdown]
# ## Timestamps

# %%
from pyspark.sql.types import LongType


df_test = df_1E6.limit(100)
df2 = (
    df_test
    .withColumn('start_time',
                f.to_timestamp('start_time',
                                 "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"))
    .withColumn('end_time',
                f.to_timestamp('end_time',
                                 "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"))
    .withColumn('tracks_start_time',
                f.to_timestamp('tracks_start_time',
                                 "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"))
    .withColumn('tracks_end_time',
                f.to_timestamp('tracks_end_time',
                                 "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"))
    .withColumn('activity_duration_seconds',
                f.col('end_time').cast(LongType()) - f.col('start_time').cast(LongType()))
)

df2.toPandas().head()
# Out:
# [('id', 'string'), ('deleted_time', 'string'), ('useruuid', 'string'), ('start_time', 'timestamp'), ('end_time', 'timestamp'), ('devices_name', 'string'), ('devices_type', 'string'), ('devices_id', 'string'), ('tracks_start_time', 'timestamp'), ('tracks_end_time', 'timestamp'), ('tracks_artist', 'string'), ('tracks_album', 'string'), ('tracks_title', 'string'), ('tracks_uri', 'string'), ('tracks_player', 'string'), ('tracks_id', 'string'), ('yearmonth', 'int'), ('activity_duration_seconds', 'bigint')]
#                                                 id deleted_time  \
# 0  96c4958e-781b-477c-9823-6a6fc5cdfed0-2016-10-16
# 1  a8eec483-caa5-4297-ab53-12dfae409b44-2016-10-16
# 2  741a6351-cd04-47ce-bfa0-c906848ca52f-2016-10-16
# 3  2720ff80-e5f3-4a92-a8cd-5f7840b2743a-2016-10-16
# 4  2868bc0a-1fb3-4020-8706-811ae31f9f92-2016-10-16
#
#                                useruuid              start_time  \
# 0  217abb4b-cf26-4b28-a1af-bfa0565f64d8 2016-10-16 11:14:24.281
# 1  d98eb3db-d1b5-47a3-a6cd-7f8b651913e0 2016-10-16 12:05:13.901
# 2  07b500bf-b975-4fc1-b203-d25973809a8a 2016-10-16 09:07:44.666
# 3  0f0742d4-454f-4234-a7aa-6980eeedf5fa 2016-10-16 08:37:42.058
# 4  5f500365-af05-4ff0-ae64-abacd71eac06 2016-10-16 10:59:54.106
#
#                  end_time devices_name devices_type        devices_id  \
# 0 2016-10-16 11:58:41.070        D6503        PHONE  30575b739121b7a7
# 1 2016-10-16 12:15:11.685        D5503        PHONE   c9d2ad0a5e3b17a
# 2 2016-10-16 11:45:58.478        E6633        PHONE  84b6ce0d67c6ab0c
# 3 2016-10-16 12:30:59.929       SO-03F        PHONE  5e0957ef6094f22f
# 4 2016-10-16 11:21:26.814        E6653        PHONE  a4b2701122758f84
#
#         tracks_start_time         tracks_end_time tracks_artist  \
# 0 2016-10-16 11:42:33.218 2016-10-16 11:45:42.689     <unknown>
# 1 2016-10-16 12:08:19.172 2016-10-16 12:09:07.304  ROMAIN VIRGO
# 2 2016-10-16 10:10:43.036 2016-10-16 10:14:48.150      Ma muzik
# 3 2016-10-16 09:38:21.892 2016-10-16 09:44:09.193     <unknown>
# 4 2016-10-16 11:03:12.722 2016-10-16 11:08:09.438     <unknown>
#
#                                         tracks_album  \
# 0                                                mp3
# 1  CORNER SHOP RIDDIM [FULL PROMO] - 21ST HAPILOS...
# 2                                              Music
# 3                                              audio
# 4                                              Music
#
#                                   tracks_title  \
# 0                Maroon 5 - Maps (Lyric Video)
# 1                                BEAT YOU DOWN
# 2          Claudio Ismael - A tua escolha 2013
# 3              DaizyStripper ー Brilliant Days．
# 4  Kizomba - Philipe Monteiro - Alta Segurança
#
#                                    tracks_uri tracks_player tracks_id  \
# 0  content://media/external/audio/media/87943       Walkman
# 1  content://media/external/audio/media/18753       Walkman
# 2   content://media/external/audio/media/2549       Walkman
# 3   content://media/external/audio/media/4816       Walkman
# 4    content://media/external/audio/media/220       Walkman
#
#    yearmonth  activity_duration_seconds
# 0     201610                       2657
# 1     201610                        598
# 2     201610                       9494
# 3     201610                      13997
# 4     201610                       1292

# %% [markdown]
# ## Merging Track ID and Track URI

# %%
df2 = (
    df2
    .withColumn('track_id',
                f.concat(f.col('tracks_id'), 
                         f.col('tracks_uri')))
)

df2.toPandas().head(20)
# Out:
#                                                  id              deleted_time  \
# 0   96c4958e-781b-477c-9823-6a6fc5cdfed0-2016-10-16
# 1   a8eec483-caa5-4297-ab53-12dfae409b44-2016-10-16
# 2   741a6351-cd04-47ce-bfa0-c906848ca52f-2016-10-16
# 3   2720ff80-e5f3-4a92-a8cd-5f7840b2743a-2016-10-16
# 4   2868bc0a-1fb3-4020-8706-811ae31f9f92-2016-10-16
# 5   65290fff-d70c-41c7-9ca9-f2b22cfa5fdc-2016-10-16
# 6   2abfb220-1b29-4df0-a395-9490947ccae6-2016-10-16  2016-10-16T11:55:22.114Z
# 7   694dfcc0-5406-44ca-8739-c0c57b365dd5-2016-10-16
# 8   9dda8f1a-4409-40ef-b569-e7dcfdd45a89-2016-10-16
# 9   1c06a1a4-11e5-479d-b4eb-d430e56e8b41-2016-10-16
# 7         PHONE  39d083c10ff8583f         1476617929       1476617962
# 8         PHONE  29ff78f4b611dee3         1476581536       1476581767
# 9         PHONE  8bbf450ec7eceee9         1476619608       1476619644
# 10        PHONE  deb86e59b0d2da58         1476619057       1476619130
# 11        PHONE  e64bc006cb020c43         1476605518       1476605800
# 12        PHONE  2b673893ab1050b2         1476616418       1476616614
# 13        PHONE  dba6b1e2d7dea4b5         1476614887       1476615011
# 14        PHONE  7bf9ea7bab4fa01d         1476621018       1476621105
# 15        PHONE  90e54b2ec4b07f5f         1476608177       1476608266
# 16        PHONE  d5a22c9fb74dc539         1476621589       1476623489
# 17        PHONE  3be55530e6556979         1476624074       1476624297
# 18        PHONE  c030d24e08d2152f         1476600604       1476600797
# 19        PHONE  a7e6c6a313958e08         1476596330       1476596499
#
#                                         tracks_artist  \
# 0                                           <unknown>
# 1                                        ROMAIN VIRGO
# 2                                            Ma muzik
# 3                                           <unknown>
# 4                                           <unknown>
# 5   Cali y El Dandee Ft. Juan Magan y Sebastian Yatra
# 6                                              Sum 41
# 7                                          A$AP Rocky
# 8                            Panet.co.il_Rabih-Baroud
# 9                                           <unknown>
# 10                                          <unknown>
# 11                                         サザンオールスターズ
# 12                                              Nause
# 13                                The Everly Brothers
# 14                                           Galantis
# 15                                   Carnal Diafragma
# 16                                          <unknown>
# 17                                          <unknown>
# 18                                       Molly Sanden
# 19                                          <unknown>
#
#                                          tracks_album  \
# 0                                                 mp3
# 1   CORNER SHOP RIDDIM [FULL PROMO] - 21ST HAPILOS...
# 2                                               Music
# 3                                               audio
# 4                                               Music
# 5                               www.planetaexitos.com
# 6   The Best of Sum 41: 8 Years of Blood, Sake and...
# 7                                   AT.LONG.LAST.A$AP
# 8                                     www.panet.co.il
# 9                                            Download
# 10  English Now! Listening and Speaking in Everyda...
# 11                                           海のYeah!!
# 12                     Dynamite (feat. Pretty Sister)
# 13               The Very Best of The Everly Brothers
# 14                                         Zaycev.Net
# 15                           Space Symphony Around Us
# 16                                           Download
# 17                                                SIA
# 18                                              Music
# 19                                After All This Time
#
#                                      tracks_title  \
# 0                   Maroon 5 - Maps (Lyric Video)
# 1                                   BEAT YOU DOWN
# 2             Claudio Ismael - A tua escolha 2013
# 3                 DaizyStripper ー Brilliant Days．
# 4     Kizomba - Philipe Monteiro - Alta Segurança
# 5                             Por Fin Te Encontré
# 6                                     Handle This
# 7              Lord Pretty Flacko Jodye 2 (LPFJ2)
# 8                                           Taibo
# 9                               TairoJ'étais prêt
# 10                                            045
# 11                                          真夏の果実
# 12                 Dynamite (feat. Pretty Sister)
# 13                           Wake Up Little Susie
# 14                          No Money (zaycev.net)
# 15                                 01 Teletrambus
# 16           The Chainsmokers - Closer ft. Halsey
# 17  Flo Rida - Wild Ones ft. Sia [Official Video]
# 18                                        Phoenix
# 19                    02 Someone Had To Teach You
#
#                                      tracks_uri tracks_player  \
# 0    content://media/external/audio/media/87943       Walkman
# 1    content://media/external/audio/media/18753       Walkman
# 2     content://media/external/audio/media/2549       Walkman
# 3     content://media/external/audio/media/4816       Walkman
# 4      content://media/external/audio/media/220       Walkman
# 5    content://media/external/audio/media/73063       Walkman
# 6     content://media/external/audio/media/8402       Walkman
# 7                                                     Spotify
# 8   content://media/external/audio/media/338585       Walkman
# 9    content://media/external/audio/media/27003       Walkman
# 10  content://media/external/audio/media/144653       Walkman
# 11    content://media/external/audio/media/4999       Walkman
# 12                                                    Spotify
# 13                                                    Spotify
# 14   content://media/external/audio/media/32494       Walkman
# 15    content://media/external/audio/media/9454       Walkman
# 16   content://media/external/audio/media/91025       Walkman
# 17   content://media/external/audio/media/48620       Walkman
# 18  content://media/external/audio/media/206438       Walkman
# 19   content://media/external/audio/media/70024       Walkman
#
#                                tracks_id  yearmonth  \
# 0                                            201610
# 1                                            201610
# 2                                            201610
# 3                                            201610
# 4                                            201610
# 5                                            201610
# 6                                            201610
# 7   spotify:track:1j6kDJttn6wbVyMaM42Nxm     201610
# 8                                            201610
# 9                                            201610
# 10                                           201610
# 11                                           201610
# 12  spotify:track:2Ae5awwKvQpTBKQHr1TYCg     201610
# 13  spotify:track:11fNLqDB47gMKj7BHhR2Qr     201610
# 14                                           201610
# 15                                           201610
# 16                                           201610
# 17                                           201610
# 18                                           201610
# 19                                           201610
#
#     activity_duration_seconds                                     track_id
# 0                        2657   content://media/external/audio/media/87943
# 1                         598   content://media/external/audio/media/18753
# 2                        9494    content://media/external/audio/media/2549
# 3                       13997    content://media/external/audio/media/4816
# 4                        1292     content://media/external/audio/media/220
# 5                        5045   content://media/external/audio/media/73063
# 6                        7323    content://media/external/audio/media/8402
# 7                        1018         spotify:track:1j6kDJttn6wbVyMaM42Nxm
# 8                        2782  content://media/external/audio/media/338585
# 9                          36   content://media/external/audio/media/27003
# 10                         73  content://media/external/audio/media/144653
# 11                       4119    content://media/external/audio/media/4999
# 12                       5148         spotify:track:2Ae5awwKvQpTBKQHr1TYCg
# 13                        706         spotify:track:11fNLqDB47gMKj7BHhR2Qr
# 14                       7911   content://media/external/audio/media/32494
# 15                      12109    content://media/external/audio/media/9454
# 16                       1900   content://media/external/audio/media/91025
# 17                        437   content://media/external/audio/media/48620
# 18                       2102  content://media/external/audio/media/206438
# 19                      32939   content://media/external/audio/media/70024

# %% [markdown]
# # Cleaning
# <hr style="border:2px solid black"></hr>

# %% [markdown]
# ## Replacing start and end time with start time and duration

# %%
time_format = "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"

df_clean = (
    df_sample_raw
    .withColumn('start_time',
                f.to_timestamp('start_time', time_format))
    .withColumn('end_time',
                f.to_timestamp('end_time', time_format))
    .withColumn('activity_duration',
                f.col('end_time').cast(LongType()) 
                - f.col('start_time').cast(LongType()))   
    .withColumn('tracks_start_time',
                f.to_timestamp('tracks_start_time', time_format))
    .withColumn('tracks_end_time',
                f.to_timestamp('tracks_end_time', time_format))
    .withColumn('track_duration',
                f.col('tracks_end_time').cast(LongType()) 
                - f.col('tracks_start_time').cast(LongType()))
    .drop('end_time')
    .drop('tracks_end_time')
)

df_clean_activity_id.limit(10).toPandas().head(10)
# Out:
#                                                 id deleted_time  \
# 0  96c4958e-781b-477c-9823-6a6fc5cdfed0-2016-10-16
# 1  a8eec483-caa5-4297-ab53-12dfae409b44-2016-10-16
# 2  741a6351-cd04-47ce-bfa0-c906848ca52f-2016-10-16
#
#                                useruuid              start_time devices_name  \
# 0  217abb4b-cf26-4b28-a1af-bfa0565f64d8 2016-10-16 11:14:24.281        D6503
# 1  d98eb3db-d1b5-47a3-a6cd-7f8b651913e0 2016-10-16 12:05:13.901        D5503
# 2  07b500bf-b975-4fc1-b203-d25973809a8a 2016-10-16 09:07:44.666        E6633
#
#   devices_type        devices_id              tracks_start_time  \
# 0        PHONE  30575b739121b7a7  2016-10-16T11:42:33.218+02:00
# 1        PHONE   c9d2ad0a5e3b17a  2016-10-16T12:08:19.172+02:00
# 2        PHONE  84b6ce0d67c6ab0c  2016-10-16T13:10:43.036+05:00
#
#                  tracks_end_time tracks_artist  \
# 0  2016-10-16T11:45:42.689+02:00     <unknown>
# 1  2016-10-16T12:09:07.304+02:00  ROMAIN VIRGO
# 2  2016-10-16T13:14:48.150+05:00      Ma muzik
#
#                                         tracks_album  \
# 0                                                mp3
# 1  CORNER SHOP RIDDIM [FULL PROMO] - 21ST HAPILOS...
# 2                                              Music
#
#                           tracks_title  \
# 0        Maroon 5 - Maps (Lyric Video)
# 1                        BEAT YOU DOWN
# 2  Claudio Ismael - A tua escolha 2013
#
#                                    tracks_uri tracks_player tracks_id  \
# 0  content://media/external/audio/media/87943       Walkman
# 1  content://media/external/audio/media/18753       Walkman
# 2   content://media/external/audio/media/2549       Walkman
#
#    yearmonth  activity_duration
# 0     201610               2657
# 1     201610                598
# 2     201610               9494

# %% [markdown]
# ## Dropping duplicates of activity id (keeping the most recent)

# %%
number_of_records = 3.5e9

df_sample_raw = df_raw.sample(fracti,uhion=1e5 / number_of_records,
                              withReplacement=False)

# %%
n_rows_before = df_sample_raw.count()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8dd4117ee56e> in <module>
# ----> 1 n_rows_before = df_sample_raw.count()
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/dataframe.py in count(self)
#     583         2
#     584         """
# --> 585         return int(self._jdf.count())
#     586
#     587     @ignore_unicode_prefix
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~/.conda/envs/env_bigdata/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(f'Rows before: {n_rows_before}')

# %%
from pyspark.sql import Window

start_time = time.time()

time_format = "yyyy-MM-dd'T'HH:mm:ss.SSSXXX"

# Define a partitioning by activity id
window_id = Window.partitionBy('id')

# Drop
df_clean = (
    df_sample_raw
    
    # Convert the start time to timestamp.
    .withColumn('start_time',
                f.to_timestamp('start_time', time_format)) 
    
    # Save the latest start time for each activity ID in a 
    # separate column.
    .withColumn('latest_start_time', f.max('start_time').over(window_id))
    
    # Delete the column containing the lates start time.
    .drop('latest_start_time')
    
    # Get only the first occurrence of each activity ID.
    .dropDuplicates('id')
)

print(f'Execution time: {time.time() - start_time:.5f} s.')

df_clean.limit(5).toPandas().head()
# Out:
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-17-13c0c4f84afc> in <module>
#      10 # Drop
#      11 df_clean = (
# ---> 12     df_sample_raw
#      13
#      14     # Convert the start time to timestamp.
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/dataframe.py in dropDuplicates(self, subset)
#    1670             jdf = self._jdf.dropDuplicates()
#    1671         else:
# -> 1672             jdf = self._jdf.dropDuplicates(self._jseq(subset))
#    1673         return DataFrame(jdf, self.sql_ctx)
#    1674
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/dataframe.py in _jseq(self, cols, converter)
#    1200     def _jseq(self, cols, converter=None):
#    1201         """Return a JVM Seq of Columns from a list of Column or names"""
# -> 1202         return _to_seq(self.sql_ctx._sc, cols, converter)
#    1203
#    1204     def _jmap(self, jm):
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/column.py in _to_seq(sc, cols, converter)
#      67     if converter:
#      68         cols = [converter(c) for c in cols]
# ---> 69     return sc._jvm.PythonUtils.toSeq(cols)
#      70
#      71
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     129     def deco(*a, **kw):
#     130         try:
# --> 131             return f(*a, **kw)
#     132         except py4j.protocol.Py4JJavaError as e:
#     133             converted = convert_exception(e.java_exception)
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     328                     format(target_id, ".", name), value)
#     329             else:
# --> 330                 raise Py4JError(
#     331                     "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                     format(target_id, ".", name, value))
#
# Py4JError: An error occurred while calling z:org.apache.spark.api.python.PythonUtils.toSeq. Trace:
# py4j.Py4JException: Method toSeq([class java.lang.String]) does not exist
# 	at py4j.reflection.ReflectionEngine.getMethod(ReflectionEngine.java:318)
# 	at py4j.reflection.ReflectionEngine.getMethod(ReflectionEngine.java:339)
# 	at py4j.Gateway.invoke(Gateway.java:276)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:745)

# %%
n_rows_after = df_clean.count()

print(f'Rows before: {n_rows_before}')
print(f'Rows after: {n_rows_after}')

# %%
w = Window.partitionBy('id')
w_t = Window.partitionBy('start_time')
b = (
    df_sample_raw
    .withColumn('id_occurrences', f.count('id').over(w))
    .where(f.col('id_occurrences') > 1)
    .groupBy('id')
    .agg(f.countDistinct('start_time').alias('n_start_time'),
         f.min('start_time').alias('min_start_time'),
         f.max('start_time').alias('max_start_time'))
    .sort(f.desc('n_start_time'))
#     .select('id', 'id_occurrences', 'start_time', 'time_occurrences')
)


b.limit(5).toPandas().head(5)
# Out:
#                                                 id  n_start_time  \
# 0  02583b73-a5d6-4fa4-84d2-a78d5bc966e1-2016-09-01             1
# 1  858e79d3-86cf-45f9-aa86-4e0dd3601899-2016-03-30             1
# 2  9b364b08-2188-4e03-9841-580335c50617-2016-12-13             1
# 3  c1c38e4b-b2d9-4251-bb34-bf1969272155-2015-07-29             1
# 4  0f0b55d7-0e31-4c95-92c9-d5d6cb910524-2015-06-03             1
#
#                   min_start_time                 max_start_time
# 0  2016-09-01T23:07:38.197+02:00  2016-09-01T23:07:38.197+02:00
# 1  2016-03-31T01:40:02.784+09:00  2016-03-31T01:40:02.784+09:00
# 2       2016-12-13T08:12:55.715Z       2016-12-13T08:12:55.715Z
# 3  2015-07-29T09:14:27.522+09:00  2015-07-29T09:14:27.522+09:00
# 4  2015-06-03T18:25:55.452+08:00  2015-06-03T18:25:55.452+08:00

# %%
df_clean_activity_id = (
    df_clean_activity_id
    .groupBy('id')
    .withCol

)

df_clean_activity_id = (
    df_clean_activity_id
    .orderBy(f.desc('start_time'))
#     .withColumn('start_time',
#                 f.to_timestamp('start_time', time_format))
#     .withColumn('end_time',
#                 f.to_timestamp('end_time', time_format))
#     .withColumn('activity_duration',
#                 f.col('end_time').cast(LongType()) 
#                 - f.col('start_time').cast(LongType()))
    
#     .withColumn('tracks_start_time',
#                 f.to_timestamp('tracks_start_time', time_format))
#     .withColumn('tracks_end_time',
#                 f.to_timestamp('tracks_end_time', time_format))
#     .withColumn('track_duration',
#                 f.col('tracks_end_time').cast(LongType()) 
#                 - f.col('tracks_start_time').cast(LongType()))
#     .drop('end_time')
#     .drop('tracks_end_time')
)

print(f'Execution time: {time.time() - start_time:.5f} s.')

df_clean_activity_id.limit(3).toPandas().head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-9220dc1a64ea> in <module>
#      23 )
#      24
# ---> 25 df_clean_activity_id.limit(3).toPandas().head()
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/pandas/conversion.py in toPandas(self)
#     136
#     137         # Below is toPandas without Arrow optimization.
# --> 138         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     139         column_counter = Counter(self.columns)
#     140
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/pyspark/sql/dataframe.py in collect(self)
#     594         """
#     595         with SCCallSiteSync(self._sc) as css:
# --> 596             sock_info = self._jdf.collectToPython()
#     597         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     598
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# ~/.conda/envs/env_bigdata/lib/python3.8/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~/.conda/envs/env_bigdata/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Drop redundant columns

# %% [markdown]
# Let's remove the columns:
#
# * `deleted_time`
# * `devices_type`
# * `yearmonth`

# %%
df_clean = (
    df_full
    .drop('deleted_time')
    .drop('devices_type')
    .drop('yearmonth')
)

df_clean.limit(3).toPandas().head()
# Out:
#                                                 id  \
# 0  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
# 1  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
# 2  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
#
#                                useruuid                     start_time  \
# 0  92e17ec9-982c-4e02-8ce4-76b19728ddf7  2016-10-16T18:31:56.512+08:00
# 1  92e17ec9-982c-4e02-8ce4-76b19728ddf7  2016-10-16T18:31:56.512+08:00
# 2  92e17ec9-982c-4e02-8ce4-76b19728ddf7  2016-10-16T18:31:56.512+08:00
#
#                         end_time devices_name        devices_id  \
# 0  2016-10-16T18:52:01.608+08:00        E6853  e6211e25cf8fd7bc
# 1  2016-10-16T18:52:01.608+08:00        E6853  e6211e25cf8fd7bc
# 2  2016-10-16T18:52:01.608+08:00        E6853  e6211e25cf8fd7bc
#
#                tracks_start_time                tracks_end_time tracks_artist  \
# 0  2016-10-16T18:31:56.512+08:00  2016-10-16T18:35:03.980+08:00     <unknown>
# 1  2016-10-16T18:35:03.980+08:00  2016-10-16T18:36:42.627+08:00     <unknown>
# 2  2016-10-16T18:36:42.627+08:00  2016-10-16T18:37:17.290+08:00     <unknown>
#
#   tracks_album                 tracks_title  \
# 0    bluetooth                   GINTAMA 曇天
# 1    bluetooth                    GunXSword
# 2    bluetooth  i jubeat knit~LOVE&JOY-木村由姬
#
#                                   tracks_uri tracks_player tracks_id
# 0  content://media/external/audio/media/1600       Walkman
# 1  content://media/external/audio/media/1601       Walkman
# 2  content://media/external/audio/media/1603       Walkman

# %% [markdown]
# ## Merging Track ID and Track URI

# %%
df_clean = (
    df_clean
    .withColumn('track_id',
                f.concat(f.col('tracks_id'), 
                         f.col('tracks_uri')))
    .drop('tracks_id')
    .drop('tracks_uri')
)

df_clean.limit(3).toPandas().head()
# Out:
#                                                 id  \
# 0  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
# 1  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
# 2  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16
#
#                                useruuid              start_time devices_name  \
# 0  92e17ec9-982c-4e02-8ce4-76b19728ddf7 2016-10-16 12:31:56.512        E6853
# 1  92e17ec9-982c-4e02-8ce4-76b19728ddf7 2016-10-16 12:31:56.512        E6853
# 2  92e17ec9-982c-4e02-8ce4-76b19728ddf7 2016-10-16 12:31:56.512        E6853
#
#          devices_id       tracks_start_time tracks_artist tracks_album  \
# 0  e6211e25cf8fd7bc 2016-10-16 12:31:56.512     <unknown>    bluetooth
# 1  e6211e25cf8fd7bc 2016-10-16 12:35:03.980     <unknown>    bluetooth
# 2  e6211e25cf8fd7bc 2016-10-16 12:36:42.627     <unknown>    bluetooth
#
#                   tracks_title tracks_player  activity_duration  \
# 0                   GINTAMA 曇天       Walkman               1205
# 1                    GunXSword       Walkman               1205
# 2  i jubeat knit~LOVE&JOY-木村由姬       Walkman               1205
#
#    track_duration                                   track_id
# 0             187  content://media/external/audio/media/1600
# 1              99  content://media/external/audio/media/1601
# 2              35  content://media/external/audio/media/1603

# %% [markdown]
# ## Rename and organize columns

# %%
start_time = time.time()

df_clean = (
    df_clean
    .withColumnRenamed('id', 'activity_id')
    .withColumnRenamed('useruuid', 'user_id')
    .withColumnRenamed('start_time', 'activity_start_time')
    .withColumnRenamed('devices_name', 'device_name')
    .withColumnRenamed('devices_id', 'device_id')
    .withColumnRenamed('tracks_start_time', 'track_start_time')
    .withColumnRenamed('tracks_artist', 'track_artist')
    .withColumnRenamed('tracks_album', 'track_album')
    .withColumnRenamed('tracks_title', 'track_title')
    .withColumnRenamed('tracks_player', 'track_player')
    .select('activity_id', 'activity_start_time', 'activity_duration',
            'user_id',
            'device_id', 'device_name',
            'track_id', 'track_artist', 'track_title', 'track_album',
            'track_player', 'track_start_time', 'track_duration')
)

print(f'Execution time: {time.time() - start_time:.5f} s.')

df_clean.limit(3).toPandas().head()
# Out:
# Execution time: 0.08106 s.
#                                        activity_id     activity_start_time  \
# 0  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16 2016-10-16 12:31:56.512
# 1  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16 2016-10-16 12:31:56.512
# 2  4302e6a4-d970-404f-a7a8-4297164d6aa6-2016-10-16 2016-10-16 12:31:56.512
#
#    activity_duration                               user_id         device_id  \
# 0               1205  92e17ec9-982c-4e02-8ce4-76b19728ddf7  e6211e25cf8fd7bc
# 1               1205  92e17ec9-982c-4e02-8ce4-76b19728ddf7  e6211e25cf8fd7bc
# 2               1205  92e17ec9-982c-4e02-8ce4-76b19728ddf7  e6211e25cf8fd7bc
#
#   device_name                                   track_id track_artist  \
# 0       E6853  content://media/external/audio/media/1600    <unknown>
# 1       E6853  content://media/external/audio/media/1601    <unknown>
# 2       E6853  content://media/external/audio/media/1603    <unknown>
#
#                    track_title track_album track_player  \
# 0                   GINTAMA 曇天   bluetooth      Walkman
# 1                    GunXSword   bluetooth      Walkman
# 2  i jubeat knit~LOVE&JOY-木村由姬   bluetooth      Walkman
#
#          track_start_time  track_duration
# 0 2016-10-16 12:31:56.512             187
# 1 2016-10-16 12:35:03.980              99
# 2 2016-10-16 12:36:42.627              35

# %% [markdown]
# ## Investigate Track Artist

# %%
start_time = time.time()

n_rows_unknown_artist = (
    df_clean
    .where(
        (f.col('track_artist').isNull())
        | (f.col('track_artist') == '')
        | (f.col('track_artist') == '<unknown>')
    )
    .count()
)

print(f'Number rows where artist is unknown: {n_rows_unknown_artist}.')
print(f'That constitutes '
      f'{n_rows_unknown_artist / number_of_rows_full * 100:.5f} % '
      f'of the total number of cells.')
print(f'Execution time: {time.time() - start_time:.5f} s.')
# Out:
# Number rows where artist is unknown: 801504143.
# That constitutes 22.44306 % of the total number of cells.
# Execution time: 1031.07266 s.
